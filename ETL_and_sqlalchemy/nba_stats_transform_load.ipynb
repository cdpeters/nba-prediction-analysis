# %% [markdown]
# # Transform and Load Stages

# %%
import time
import tomllib
from pathlib import Path

import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Read in the CSVs

# %%
data_dir = Path.cwd().joinpath("data")

# Team Stats -------------------------------------------------------------------
with open(data_dir.joinpath("stat_types_and_seasons.txt"), "r") as f:
    data = f.read()
    stat_types = data.split("\n")[:-1]

all_stats = {}
for season_type in ["Regular Season", "Playoffs"]:
    stats = {}
    for stat_type in stat_types:
        # Split and join the stat_type string with underscores for the filepath
        # below.
        split_string = stat_type.split()
        stat_type_underscores = "_".join(split_string).lower()
        if season_type == "Playoffs":
            stat_type_underscores = f"playoffs_{stat_type_underscores}"

        # Create filepath for reading from
        table_filepath = data_dir.joinpath(f"{stat_type_underscores}.csv")

        # Read the DataFrame from file
        stats_df = pd.read_csv(table_filepath)
        stats[stat_type] = stats_df
    all_stats[season_type] = stats
team_stats = all_stats["Regular Season"]
team_stats_playoffs = all_stats["Playoffs"]

# Playoffs ---------------------------------------------------------------------
playoff_teams_filepath = data_dir.joinpath("playoff_teams_df.csv")
playoff_teams_df = pd.read_csv(playoff_teams_filepath)

# Champions --------------------------------------------------------------------
champions_filepath = data_dir.joinpath("champions_df.csv")
champions_df = pd.read_csv(champions_filepath)

# %%
team_stats.keys()
# Out:
# dict_keys(['Teams General Traditional', 'Teams General Advanced', 'Teams General Misc', 'Teams Clutch Traditional'])

# %% [markdown]
# ### Test That the Data Loaded Correctly

# %%
print("Teams General Traditional length:", len(team_stats["Teams General Traditional"]))
print("Teams General Advanced length:", len(team_stats["Teams General Advanced"]))
print("Teams General Misc length:", len(team_stats["Teams General Misc"]))
print("Teams Clutch Traditional length:", len(team_stats["Teams Clutch Traditional"]))
team_stats["Teams General Advanced"]
# Out:
# Teams General Traditional length: 806
# Teams General Advanced length: 806
# Teams General Misc length: 806
# Teams Clutch Traditional length: 804
#       SEASON                   TEAM  GP   W   L     MIN  OFFRTG  DEFRTG  \
# 0    2023-24         Denver Nuggets   1   1   0    48.0   125.3   111.5
# 1    2023-24           Phoenix Suns   1   1   0    48.0   106.9   102.0
# 2    2023-24  Golden State Warriors   1   0   1    48.0   102.0   106.9
# 3    2023-24     Los Angeles Lakers   1   0   1    48.0   111.5   125.3
# 4    2022-23        Milwaukee Bucks  82  58  24  3966.0   114.3   110.9
# ..       ...                    ...  ..  ..  ..     ...     ...     ...
# 801  1996-97     Philadelphia 76ers  82  22  60  3956.0   102.6   109.5
# 802  1996-97         Denver Nuggets  82  21  61  3986.0   103.1   109.7
# 803  1996-97      San Antonio Spurs  82  20  62  3946.0   102.1   110.8
# 804  1996-97         Boston Celtics  82  15  67  3981.0   102.9   110.1
# 805  1996-97    Vancouver Grizzlies  82  14  68  3956.0    99.1   110.1
#
#      NETRTG  AST%  ...  ASTRATIO  OREB%  DREB%  REB%  TOV%  EFG%   TS%  \
# 0      13.8  60.4  ...      21.2   28.9   65.4  48.5  12.6  60.4  61.8
# 1       5.0  54.8  ...      15.9   39.6   64.2  53.3  18.8  50.0  52.7
# 2      -5.0  52.8  ...      13.1   35.8   60.4  46.7  10.8  40.6  45.9
# 3     -13.8  56.1  ...      16.8   34.6   71.1  51.5  12.5  51.1  54.1
# 4       3.4  60.4  ...      18.1   28.4   74.5  52.1  14.3  55.5  58.3
# ..      ...   ...  ...       ...    ...    ...   ...   ...   ...   ...
# 801    -6.9  56.4  ...      15.2   35.9   65.4  50.4  17.9  47.0  51.8
# 802    -6.6  64.4  ...      17.4   32.4   66.6  49.6  17.5  48.6  53.0
# 803    -8.8  58.8  ...      16.3   34.4   64.3  49.0  17.1  47.2  51.2
# 804    -7.2  58.4  ...      16.1   32.9   65.8  48.2  16.7  47.4  52.0
# 805   -11.0  66.1  ...      17.9   32.5   61.8  46.9  17.6  47.1  50.7
#
#        PACE   PIE    POSS
# 0     95.50  57.9    95.0
# 1    101.50  56.4   101.0
# 2    101.50  43.6   102.0
# 3     95.50  42.1    96.0
# 4    101.45  52.3  8389.0
# ..      ...   ...     ...
# 801   97.05  45.3  8006.0
# 802   93.67  46.1  7776.0
# 803   88.45  44.0  7268.0
# 804   96.78  43.4  8014.0
# 805   89.70  43.3  7380.0
#
# [806 rows x 21 columns]

# %%
print(
    "Playoffs Teams General Traditional length:",
    len(team_stats_playoffs["Teams General Traditional"]),
)
print(
    "Playoffs Teams General Advanced length:",
    len(team_stats_playoffs["Teams General Advanced"]),
)
print(
    "Playoffs Teams General Misc length:",
    len(team_stats_playoffs["Teams General Misc"]),
)
print(
    "Playoffs Teams Clutch Traditional length:",
    len(team_stats_playoffs["Teams Clutch Traditional"]),
)
team_stats_playoffs["Teams General Advanced"]
# Out:
# Playoffs Teams General Traditional length: 432
# Playoffs Teams General Advanced length: 432
# Playoffs Teams General Misc length: 432
# Playoffs Teams Clutch Traditional length: 421
#       SEASON                    TEAM  GP   W   L     MIN  OFFRTG  DEFRTG  \
# 0    2022-23          Denver Nuggets  20  16   4   965.0   118.2   110.2
# 1    2022-23              Miami Heat  23  13  10  1109.0   113.8   111.9
# 2    2022-23          Boston Celtics  20  11   9   965.0   116.1   112.9
# 3    2022-23      Los Angeles Lakers  16   8   8   773.0   112.7   110.3
# 4    2022-23      Philadelphia 76ers  11   7   4   533.0   110.2   112.1
# ..       ...                     ...  ..  ..  ..     ...     ...     ...
# 427  1996-97  Portland Trail Blazers   4   1   3   192.0   102.6   109.9
# 428  1996-97       Charlotte Hornets   3   0   3   144.0   107.1   117.7
# 429  1996-97    Los Angeles Clippers   3   0   3   144.0   104.9   118.9
# 430  1996-97  Minnesota Timberwolves   3   0   3   144.0   111.2   122.9
# 431  1996-97      Washington Bullets   3   0   3   144.0   105.6   111.8
#
#      NETRTG  AST%  ...  ASTRATIO  OREB%  DREB%  REB%  TOV%  EFG%   TS%   PACE  \
# 0       8.0  60.9  ...      19.1   30.0   76.2  53.8  12.1  55.7  59.3  95.18
# 1       1.9  59.3  ...      17.9   27.2   70.8  48.7  12.3  53.1  56.7  94.87
# 2       3.2  59.1  ...      18.2   26.6   71.6  49.7  12.9  56.0  59.4  95.83
# 3       2.4  60.7  ...      18.2   26.1   70.9  49.8  12.0  52.9  57.3  99.04
# 4      -2.0  52.0  ...      15.2   29.6   76.6  52.7  13.3  51.0  55.5  92.08
# ..      ...   ...  ...       ...    ...    ...   ...   ...   ...   ...    ...
# 427    -7.4  60.3  ...      16.4   29.9   66.5  47.8  17.7  47.9  52.8  87.75
# 428   -10.6  50.5  ...      14.9   35.5   74.8  52.3  14.9  49.2  53.5  89.00
# 429   -13.9  50.0  ...      14.0   26.8   63.5  43.2  13.6  47.6  52.7  88.17
# 430   -11.7  60.0  ...      18.6   31.6   63.6  46.1  10.4  48.7  51.6  90.00
# 431    -6.3  50.0  ...      14.2   32.8   60.4  47.7  20.7  50.5  56.3  90.17
#
#       PIE    POSS
# 0    55.3  1919.0
# 1    49.8  2189.0
# 2    52.6  1929.0
# 3    53.2  1595.0
# 4    48.3  1024.0
# ..    ...     ...
# 427  41.8   350.0
# 428  42.0   268.0
# 429  36.2   264.0
# 430  42.5   269.0
# 431  45.5   270.0
#
# [432 rows x 21 columns]

# %%
playoff_teams_df
# Out:
#                    2022-23                 2021-22                 2020-21  \
# 0           Denver Nuggets   Golden State Warriors         Milwaukee Bucks
# 1               Miami Heat          Boston Celtics            Phoenix Suns
# 2           Boston Celtics              Miami Heat           Atlanta Hawks
# 3       Los Angeles Lakers        Dallas Mavericks             LA Clippers
# 4       Philadelphia 76ers         Milwaukee Bucks           Brooklyn Nets
# 5          New York Knicks            Phoenix Suns      Philadelphia 76ers
# 6             Phoenix Suns       Memphis Grizzlies               Utah Jazz
# 7    Golden State Warriors      Philadelphia 76ers          Denver Nuggets
# 8         Sacramento Kings  Minnesota Timberwolves        Dallas Mavericks
# 9            Atlanta Hawks    New Orleans Pelicans      Los Angeles Lakers
# 10       Memphis Grizzlies         Toronto Raptors  Portland Trail Blazers
# 11     Cleveland Cavaliers               Utah Jazz          Boston Celtics
# 12             LA Clippers           Atlanta Hawks       Memphis Grizzlies
# 13         Milwaukee Bucks           Chicago Bulls         New York Knicks
# 14  Minnesota Timberwolves          Denver Nuggets      Washington Wizards
# 15           Brooklyn Nets           Brooklyn Nets              Miami Heat
#
#                    2019-20                 2018-19                 2017-18  \
# 0       Los Angeles Lakers         Toronto Raptors   Golden State Warriors
# 1               Miami Heat   Golden State Warriors     Cleveland Cavaliers
# 2           Boston Celtics         Milwaukee Bucks         Houston Rockets
# 3           Denver Nuggets  Portland Trail Blazers          Boston Celtics
# 4          Toronto Raptors      Philadelphia 76ers    New Orleans Pelicans
# 5              LA Clippers          Denver Nuggets      Philadelphia 76ers
# 6          Milwaukee Bucks         Houston Rockets               Utah Jazz
# 7          Houston Rockets          Boston Celtics         Toronto Raptors
# 8    Oklahoma City Thunder       San Antonio Spurs          Indiana Pacers
# 9                Utah Jazz             LA Clippers         Milwaukee Bucks
# 10        Dallas Mavericks           Brooklyn Nets   Oklahoma City Thunder
# 11           Orlando Magic   Oklahoma City Thunder      Washington Wizards
# 12  Portland Trail Blazers           Orlando Magic              Miami Heat
# 13           Brooklyn Nets               Utah Jazz  Minnesota Timberwolves
# 14          Indiana Pacers         Detroit Pistons       San Antonio Spurs
# 15      Philadelphia 76ers          Indiana Pacers  Portland Trail Blazers
#
#                    2016-17                 2015-16                 2014-15  \
# 0    Golden State Warriors     Cleveland Cavaliers   Golden State Warriors
# 1      Cleveland Cavaliers   Golden State Warriors     Cleveland Cavaliers
# 2           Boston Celtics   Oklahoma City Thunder         Houston Rockets
# 3        San Antonio Spurs         Toronto Raptors           Atlanta Hawks
# 4       Washington Wizards              Miami Heat    Los Angeles Clippers
# 5          Houston Rockets       San Antonio Spurs      Washington Wizards
# 6          Toronto Raptors  Portland Trail Blazers       Memphis Grizzlies
# 7                Utah Jazz           Atlanta Hawks           Chicago Bulls
# 8              LA Clippers       Charlotte Hornets       San Antonio Spurs
# 9            Atlanta Hawks          Indiana Pacers           Brooklyn Nets
# 10           Chicago Bulls          Boston Celtics         Milwaukee Bucks
# 11       Memphis Grizzlies             LA Clippers        Dallas Mavericks
# 12         Milwaukee Bucks        Dallas Mavericks  Portland Trail Blazers
# 13   Oklahoma City Thunder         Houston Rockets          Boston Celtics
# 14          Indiana Pacers         Detroit Pistons    New Orleans Pelicans
# 15  Portland Trail Blazers       Memphis Grizzlies         Toronto Raptors
#
#                    2013-14  ...               2005-06              2004-05  \
# 0        San Antonio Spurs  ...            Miami Heat    San Antonio Spurs
# 1               Miami Heat  ...      Dallas Mavericks      Detroit Pistons
# 2           Indiana Pacers  ...       Detroit Pistons           Miami Heat
# 3    Oklahoma City Thunder  ...          Phoenix Suns         Phoenix Suns
# 4       Washington Wizards  ...  Los Angeles Clippers  Seattle SuperSonics
# 5     Los Angeles Clippers  ...   Cleveland Cavaliers     Dallas Mavericks
# 6   Portland Trail Blazers  ...     San Antonio Spurs       Indiana Pacers
# 7            Brooklyn Nets  ...       New Jersey Nets   Washington Wizards
# 8            Atlanta Hawks  ...    Los Angeles Lakers       Boston Celtics
# 9         Dallas Mavericks  ...         Chicago Bulls      Houston Rockets
# 10   Golden State Warriors  ...        Indiana Pacers        Chicago Bulls
# 11       Memphis Grizzlies  ...      Sacramento Kings       Denver Nuggets
# 12         Toronto Raptors  ...    Washington Wizards   Philadelphia 76ers
# 13         Houston Rockets  ...        Denver Nuggets     Sacramento Kings
# 14           Chicago Bulls  ...       Milwaukee Bucks    Memphis Grizzlies
# 15       Charlotte Bobcats  ...     Memphis Grizzlies      New Jersey Nets
#
#                    2003-04                 2002-03                 2001-02  \
# 0          Detroit Pistons       San Antonio Spurs      Los Angeles Lakers
# 1       Los Angeles Lakers         New Jersey Nets         New Jersey Nets
# 2           Indiana Pacers        Dallas Mavericks        Sacramento Kings
# 3   Minnesota Timberwolves         Detroit Pistons          Boston Celtics
# 4          New Jersey Nets        Sacramento Kings        Dallas Mavericks
# 5         Sacramento Kings      Los Angeles Lakers       Charlotte Hornets
# 6        San Antonio Spurs      Philadelphia 76ers         Detroit Pistons
# 7               Miami Heat          Boston Celtics       San Antonio Spurs
# 8      New Orleans Hornets           Orlando Magic          Indiana Pacers
# 9         Dallas Mavericks  Portland Trail Blazers      Philadelphia 76ers
# 10          Denver Nuggets          Indiana Pacers     Seattle SuperSonics
# 11         Houston Rockets         Milwaukee Bucks         Toronto Raptors
# 12         Milwaukee Bucks  Minnesota Timberwolves           Orlando Magic
# 13          Boston Celtics     New Orleans Hornets               Utah Jazz
# 14       Memphis Grizzlies            Phoenix Suns  Minnesota Timberwolves
# 15         New York Knicks               Utah Jazz  Portland Trail Blazers
#
#                    2000-01                 1999-00                 1998-99  \
# 0       Los Angeles Lakers      Los Angeles Lakers       San Antonio Spurs
# 1       Philadelphia 76ers          Indiana Pacers         New York Knicks
# 2          Milwaukee Bucks  Portland Trail Blazers          Indiana Pacers
# 3        San Antonio Spurs         New York Knicks  Portland Trail Blazers
# 4        Charlotte Hornets              Miami Heat               Utah Jazz
# 5          Toronto Raptors      Philadelphia 76ers      Los Angeles Lakers
# 6         Dallas Mavericks            Phoenix Suns      Philadelphia 76ers
# 7         Sacramento Kings               Utah Jazz           Atlanta Hawks
# 8          New York Knicks         Milwaukee Bucks         Detroit Pistons
# 9                Utah Jazz        Sacramento Kings              Miami Heat
# 10          Indiana Pacers     Seattle SuperSonics        Sacramento Kings
# 11  Minnesota Timberwolves       Charlotte Hornets         Houston Rockets
# 12           Orlando Magic  Minnesota Timberwolves  Minnesota Timberwolves
# 13            Phoenix Suns       San Antonio Spurs           Orlando Magic
# 14              Miami Heat         Detroit Pistons         Milwaukee Bucks
# 15  Portland Trail Blazers         Toronto Raptors            Phoenix Suns
#
#                    1997-98                 1996-97
# 0            Chicago Bulls           Chicago Bulls
# 1                Utah Jazz               Utah Jazz
# 2           Indiana Pacers         Houston Rockets
# 3       Los Angeles Lakers              Miami Heat
# 4        Charlotte Hornets         New York Knicks
# 5        San Antonio Spurs     Seattle SuperSonics
# 6          New York Knicks      Los Angeles Lakers
# 7      Seattle SuperSonics           Atlanta Hawks
# 8          Houston Rockets         Detroit Pistons
# 9               Miami Heat           Orlando Magic
# 10  Minnesota Timberwolves            Phoenix Suns
# 11           Atlanta Hawks  Portland Trail Blazers
# 12     Cleveland Cavaliers       Charlotte Hornets
# 13            Phoenix Suns    Los Angeles Clippers
# 14  Portland Trail Blazers  Minnesota Timberwolves
# 15         New Jersey Nets      Washington Bullets
#
# [16 rows x 27 columns]

# %%
champions_df
# Out:
#      SEASON                   TEAM
# 0   2022-23         Denver Nuggets
# 1   2021-22  Golden State Warriors
# 2   2020-21        Milwaukee Bucks
# 3   2019-20     Los Angeles Lakers
# 4   2018-19        Toronto Raptors
# 5   2017-18  Golden State Warriors
# 6   2016-17  Golden State Warriors
# 7   2015-16    Cleveland Cavaliers
# 8   2014-15  Golden State Warriors
# 9   2013-14      San Antonio Spurs
# 10  2012-13             Miami Heat
# 11  2011-12             Miami Heat
# 12  2010-11       Dallas Mavericks
# 13  2009-10     Los Angeles Lakers
# 14  2008-09     Los Angeles Lakers
# 15  2007-08         Boston Celtics
# 16  2006-07      San Antonio Spurs
# 17  2005-06             Miami Heat
# 18  2004-05      San Antonio Spurs
# 19  2003-04        Detroit Pistons
# 20  2002-03      San Antonio Spurs
# 21  2001-02     Los Angeles Lakers
# 22  2000-01     Los Angeles Lakers
# 23  1999-00     Los Angeles Lakers
# 24  1998-99      San Antonio Spurs
# 25  1997-98          Chicago Bulls
# 26  1996-97          Chicago Bulls

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Transform Stage
# ### Current Variables
#
# #### Team Stats
# * `team_stats`: *dict* of the form `{<stat_type>: <DataFrame>, ...}` with the following 4 stat_type keys:
#     * "Teams General Traditional"
#     * "Teams General Advanced"
#     * "Teams General Misc"
#     * "Teams Clutch Traditional"
#
#     <br>
#
#     * Example Usage:
#     ```python
#     team_stats["Teams General Advanced"]
#     ```
#
# #### Playoff Team Stats
# * `team_stats_playoffs`: *dict* of the form `{<stat_type>: <DataFrame>, ...}` with the following 4 stat_type keys:
#     * "Teams General Traditional"
#     * "Teams General Advanced"
#     * "Teams General Misc"
#     * "Teams Clutch Traditional"
#
#     <br>
#
#     * Example Usage:
#     ```python
#     team_stats_playoffs["Teams General Advanced"]
#     ```
#
# #### Playoff Teams
# * `playoff_teams_df`: *DataFrame*, each season is a column, and each row is a playoff team for that season
#
# #### Champions
# * `champions_df`: *DataFrame*, the index is the season and the TEAM column is the name of the champion team for that season

# %% [markdown]
# ### Seasons

# %%
seasons = team_stats["Teams General Traditional"]["SEASON"].unique()
seasons = pd.to_datetime(seasons, format="%Y-%y").year

playoff_seasons = team_stats_playoffs["Teams General Traditional"]["SEASON"].unique()
playoff_seasons = pd.to_datetime(playoff_seasons, format="%Y-%y").year

# %% [markdown]
# ### Transform `playoff_teams_df` and Create a Long Format Version of `playoff_teams_df`
# #### Convert Column Names of `playoffs_df` to the Second Year as a 4 Number Integer

# %%
playoff_teams_df.columns = playoff_seasons
playoff_teams_df = playoff_teams_df.astype(pd.StringDtype())
playoff_teams_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2023    16 non-null     string
#  1   2022    16 non-null     string
#  2   2021    16 non-null     string
#  3   2020    16 non-null     string
#  4   2019    16 non-null     string
#  5   2018    16 non-null     string
#  6   2017    16 non-null     string
#  7   2016    16 non-null     string
#  8   2015    16 non-null     string
#  9   2014    16 non-null     string
#  10  2013    16 non-null     string
#  11  2012    16 non-null     string
#  12  2011    16 non-null     string
#  13  2010    16 non-null     string
#  14  2009    16 non-null     string
#  15  2008    16 non-null     string
#  16  2007    16 non-null     string
#  17  2006    16 non-null     string
#  18  2005    16 non-null     string
#  19  2004    16 non-null     string
#  20  2003    16 non-null     string
#  21  2002    16 non-null     string
#  22  2001    16 non-null     string
#  23  2000    16 non-null     string
#  24  1999    16 non-null     string
#  25  1998    16 non-null     string
#  26  1997    16 non-null     string
# dtypes: string(27)
# memory usage: 3.5 KB

# %%
playoff_teams_df.head()
# Out:
#                  2023                   2022             2021  \
# 0      Denver Nuggets  Golden State Warriors  Milwaukee Bucks
# 1          Miami Heat         Boston Celtics     Phoenix Suns
# 2      Boston Celtics             Miami Heat    Atlanta Hawks
# 3  Los Angeles Lakers       Dallas Mavericks      LA Clippers
# 4  Philadelphia 76ers        Milwaukee Bucks    Brooklyn Nets
#
#                  2020                    2019                   2018  \
# 0  Los Angeles Lakers         Toronto Raptors  Golden State Warriors
# 1          Miami Heat   Golden State Warriors    Cleveland Cavaliers
# 2      Boston Celtics         Milwaukee Bucks        Houston Rockets
# 3      Denver Nuggets  Portland Trail Blazers         Boston Celtics
# 4     Toronto Raptors      Philadelphia 76ers   New Orleans Pelicans
#
#                     2017                   2016                   2015  \
# 0  Golden State Warriors    Cleveland Cavaliers  Golden State Warriors
# 1    Cleveland Cavaliers  Golden State Warriors    Cleveland Cavaliers
# 2         Boston Celtics  Oklahoma City Thunder        Houston Rockets
# 3      San Antonio Spurs        Toronto Raptors          Atlanta Hawks
# 4     Washington Wizards             Miami Heat   Los Angeles Clippers
#
#                     2014  ...                  2006                 2005  \
# 0      San Antonio Spurs  ...            Miami Heat    San Antonio Spurs
# 1             Miami Heat  ...      Dallas Mavericks      Detroit Pistons
# 2         Indiana Pacers  ...       Detroit Pistons           Miami Heat
# 3  Oklahoma City Thunder  ...          Phoenix Suns         Phoenix Suns
# 4     Washington Wizards  ...  Los Angeles Clippers  Seattle SuperSonics
#
#                      2004               2003                2002  \
# 0         Detroit Pistons  San Antonio Spurs  Los Angeles Lakers
# 1      Los Angeles Lakers    New Jersey Nets     New Jersey Nets
# 2          Indiana Pacers   Dallas Mavericks    Sacramento Kings
# 3  Minnesota Timberwolves    Detroit Pistons      Boston Celtics
# 4         New Jersey Nets   Sacramento Kings    Dallas Mavericks
#
#                  2001                    2000                    1999  \
# 0  Los Angeles Lakers      Los Angeles Lakers       San Antonio Spurs
# 1  Philadelphia 76ers          Indiana Pacers         New York Knicks
# 2     Milwaukee Bucks  Portland Trail Blazers          Indiana Pacers
# 3   San Antonio Spurs         New York Knicks  Portland Trail Blazers
# 4   Charlotte Hornets              Miami Heat               Utah Jazz
#
#                  1998             1997
# 0       Chicago Bulls    Chicago Bulls
# 1           Utah Jazz        Utah Jazz
# 2      Indiana Pacers  Houston Rockets
# 3  Los Angeles Lakers       Miami Heat
# 4   Charlotte Hornets  New York Knicks
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Playoff Teams (long format DataFrame)

# %%
playoff_teams_long_df = playoff_teams_df.melt(var_name="SEASON", value_name="TEAM")
playoff_teams_long_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SEASON  432 non-null    int32
#  1   TEAM    432 non-null    string
# dtypes: int32(1), string(1)
# memory usage: 5.2 KB

# %%
playoff_teams_long_df.head()
# Out:
#    SEASON                TEAM
# 0    2023      Denver Nuggets
# 1    2023          Miami Heat
# 2    2023      Boston Celtics
# 3    2023  Los Angeles Lakers
# 4    2023  Philadelphia 76ers

# %% [markdown]
# ### Transform `champions_df`

# %%
champions_df["SEASON"] = pd.to_datetime(champions_df["SEASON"], format="%Y-%y").dt.year
champions_df["TEAM"] = champions_df["TEAM"].astype(pd.StringDtype())
champions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SEASON  27 non-null     int32
#  1   TEAM    27 non-null     string
# dtypes: int32(1), string(1)
# memory usage: 456.0 bytes

# %%
champions_df.head()
# Out:
#    SEASON                   TEAM
# 0    2023         Denver Nuggets
# 1    2022  Golden State Warriors
# 2    2021        Milwaukee Bucks
# 3    2020     Los Angeles Lakers
# 4    2019        Toronto Raptors

# %% [markdown]
# ### Transform `team_stats`
# #### Transform Team Stats Helper Function

# %%
def transform_team_stats_table(stats_table_input):
    stats_table = stats_table_input.copy()
    stats_table["SEASON"] = pd.to_datetime(
        stats_table["SEASON"], format="%Y-%y"
    ).dt.year

    # Intialize PLAYOFFS and CHAMPION boolean columns
    stats_table["PLAYOFFS"] = False
    stats_table["CHAMPION"] = False

    # Loop over each season and that season's playoff teams
    for season, playoff_teams in playoff_teams_df.items():
        # Compare the teams from the `season` to `playoff_teams` from the same `season`, the boolean will be True if the team was/is a playoff team
        playoffs_boolean_column = stats_table.loc[
            stats_table["SEASON"] == season, "TEAM"
        ].isin(playoff_teams)
        stats_table.loc[
            stats_table["SEASON"] == season, "PLAYOFFS"
        ] = playoffs_boolean_column

        # Compare the teams from the `season` to the champion from the same `season`, the boolean will be True if the team was the champion team
        champion_series = champions_df.loc[
            champions_df["SEASON"] == season, "TEAM"
        ].reset_index(drop=True)
        champion = champion_series.loc[0]
        stats_table.loc[
            (stats_table["SEASON"] == season) & (stats_table["TEAM"] == champion),
            "CHAMPION",
        ] = True

    return stats_table

# %% [markdown]
# #### Transform Team Stats

# %%
for stat_type, stats_table in team_stats.items():
    team_stats[stat_type] = transform_team_stats_table(stats_table)
team_stats["Teams General Traditional"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 806 entries, 0 to 805
# Data columns (total 30 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEASON    806 non-null    int32
#  1   TEAM      806 non-null    object
#  2   GP        806 non-null    int64
#  3   W         806 non-null    int64
#  4   L         806 non-null    int64
#  5   WIN%      806 non-null    float64
#  6   MIN       806 non-null    float64
#  7   PTS       806 non-null    float64
#  8   FGM       806 non-null    float64
#  9   FGA       806 non-null    float64
#  10  FG%       806 non-null    float64
#  11  3PM       806 non-null    float64
#  12  3PA       806 non-null    float64
#  13  3P%       806 non-null    float64
#  14  FTM       806 non-null    float64
#  15  FTA       806 non-null    float64
#  16  FT%       806 non-null    float64
#  17  OREB      806 non-null    float64
#  18  DREB      806 non-null    float64
#  19  REB       806 non-null    float64
#  20  AST       806 non-null    float64
#  21  TOV       806 non-null    float64
#  22  STL       806 non-null    float64
#  23  BLK       806 non-null    float64
#  24  BLKA      806 non-null    float64
#  25  PF        806 non-null    float64
#  26  PFD       806 non-null    float64
#  27  +/-       806 non-null    float64
#  28  PLAYOFFS  806 non-null    bool
#  29  CHAMPION  806 non-null    bool
# dtypes: bool(2), float64(23), int32(1), int64(3), object(1)
# memory usage: 174.9+ KB

# %%
team_stats["Teams General Traditional"].head(10)
# Out:
#    SEASON                   TEAM  GP   W   L   WIN%   MIN    PTS   FGM    FGA  \
# 0    2024         Denver Nuggets   1   1   0  1.000  48.0  119.0  48.0   91.0
# 1    2024           Phoenix Suns   1   1   0  1.000  48.0  108.0  42.0   95.0
# 2    2024  Golden State Warriors   1   0   1  0.000  48.0  104.0  36.0  101.0
# 3    2024     Los Angeles Lakers   1   0   1  0.000  48.0  107.0  41.0   90.0
# 4    2023        Milwaukee Bucks  82  58  24  0.707  48.4  116.9  42.7   90.4
# 5    2023         Boston Celtics  82  57  25  0.695  48.7  117.9  42.2   88.8
# 6    2023     Philadelphia 76ers  82  54  28  0.659  48.5  115.2  40.8   83.8
# 7    2023         Denver Nuggets  82  53  29  0.646  48.2  115.8  43.6   86.4
# 8    2023    Cleveland Cavaliers  82  51  31  0.622  48.5  112.3  41.6   85.2
# 9    2023      Memphis Grizzlies  82  51  31  0.622  48.2  116.9  43.7   92.1
#
#    ...   AST   TOV   STL  BLK  BLKA    PF   PFD   +/-  PLAYOFFS  CHAMPION
# 0  ...  29.0  12.0   9.0  6.0   4.0  15.0  18.0  12.0     False     False
# 1  ...  23.0  19.0   5.0  7.0   6.0  22.0  23.0   4.0     False     False
# 2  ...  19.0  11.0  11.0  6.0   7.0  23.0  22.0  -4.0     False     False
# 3  ...  23.0  12.0   5.0  4.0   6.0  18.0  15.0 -12.0     False     False
# 4  ...  25.8  14.6   6.4  4.9   3.9  18.0  19.0   3.6      True     False
# 5  ...  26.7  13.4   6.4  5.2   3.9  18.8  19.1   6.5      True     False
# 6  ...  25.2  13.7   7.7  4.7   4.6  20.4  19.6   4.3      True     False
# 7  ...  28.9  14.5   7.5  4.5   4.2  18.6  19.5   3.3      True      True
# 8  ...  24.9  13.3   7.1  4.7   4.4  19.0  20.4   5.4      True     False
# 9  ...  26.0  13.6   8.3  5.8   5.2  20.0  20.0   3.9      True     False
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Transform `team_stats_playoffs`
# #### Transform Team Stats Playoffs Helper Function

# %%
def transform_team_stats_playoffs_table(stats_table_input):
    stats_table = stats_table_input.copy()
    stats_table["SEASON"] = pd.to_datetime(
        stats_table["SEASON"], format="%Y-%y"
    ).dt.year
    # Intialize CHAMPION boolean column
    stats_table["CHAMPION"] = False

    # Loop over each season and that season's playoff teams
    for season in playoff_seasons:
        # Compare the teams from the `season` to the champion from the same `season`, the boolean will be True if the team was the champion team
        champion_series = champions_df.loc[
            champions_df["SEASON"] == season, "TEAM"
        ].reset_index(drop=True)
        champion = champion_series.loc[0]
        stats_table.loc[
            (stats_table["SEASON"] == season) & (stats_table["TEAM"] == champion),
            "CHAMPION",
        ] = True

    return stats_table

# %% [markdown]
# #### Transform Team Stats Playoffs

# %%
for stat_type, playoff_stats_table in team_stats_playoffs.items():
    team_stats_playoffs[stat_type] = transform_team_stats_playoffs_table(
        playoff_stats_table
    )
team_stats_playoffs["Teams General Traditional"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 29 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEASON    432 non-null    int32
#  1   TEAM      432 non-null    object
#  2   GP        432 non-null    int64
#  3   W         432 non-null    int64
#  4   L         432 non-null    int64
#  5   WIN%      432 non-null    float64
#  6   MIN       432 non-null    float64
#  7   PTS       432 non-null    float64
#  8   FGM       432 non-null    float64
#  9   FGA       432 non-null    float64
#  10  FG%       432 non-null    float64
#  11  3PM       432 non-null    float64
#  12  3PA       432 non-null    float64
#  13  3P%       432 non-null    float64
#  14  FTM       432 non-null    float64
#  15  FTA       432 non-null    float64
#  16  FT%       432 non-null    float64
#  17  OREB      432 non-null    float64
#  18  DREB      432 non-null    float64
#  19  REB       432 non-null    float64
#  20  AST       432 non-null    float64
#  21  TOV       432 non-null    float64
#  22  STL       432 non-null    float64
#  23  BLK       432 non-null    float64
#  24  BLKA      432 non-null    float64
#  25  PF        432 non-null    float64
#  26  PFD       432 non-null    float64
#  27  +/-       432 non-null    float64
#  28  CHAMPION  432 non-null    bool
# dtypes: bool(1), float64(23), int32(1), int64(3), object(1)
# memory usage: 93.4+ KB

# %%
team_stats_playoffs["Teams General Traditional"].head(10)
# Out:
#    SEASON                   TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0    2023         Denver Nuggets  20  16   4  0.800  48.3  113.5  42.3  86.0
# 1    2023     Philadelphia 76ers  11   7   4  0.636  48.5  102.5  36.7  84.0
# 2    2023             Miami Heat  23  13  10  0.565  48.2  108.3  39.7  86.8
# 3    2023         Boston Celtics  20  11   9  0.550  48.3  112.0  40.9  85.5
# 4    2023        New York Knicks  11   6   5  0.545  48.0  100.1  35.3  81.5
# 5    2023           Phoenix Suns  11   6   5  0.545  48.0  114.2  43.1  86.8
# 6    2023     Los Angeles Lakers  16   8   8  0.500  48.3  112.3  41.1  87.1
# 7    2023  Golden State Warriors  13   6   7  0.462  48.0  113.1  41.9  93.6
# 8    2023       Sacramento Kings   7   3   4  0.429  48.0  113.7  41.0  95.6
# 9    2023          Atlanta Hawks   6   2   4  0.333  48.0  115.8  44.0  96.3
#
#    ...   REB   AST   TOV  STL  BLK  BLKA    PF   PFD  +/-  CHAMPION
# 0  ...  44.8  25.8  11.6  6.9  4.2   4.7  19.3  21.0  8.3      True
# 1  ...  43.0  19.1  12.4  7.6  5.3   5.5  18.7  16.0 -1.5     False
# 2  ...  40.3  23.6  11.7  7.0  3.6   4.7  20.1  18.7  1.5     False
# 3  ...  43.1  24.2  12.4  6.0  6.4   4.7  17.2  17.7  3.4     False
# 4  ...  45.4  18.7  14.6  7.0  4.5   3.8  19.5  21.6  0.4     False
# 5  ...  40.0  24.5  12.1  6.3  5.6   4.0  22.0  20.8 -2.3     False
# 6  ...  44.6  24.9  11.9  6.8  6.4   3.8  17.4  21.3  2.4     False
# 7  ...  47.1  28.2  14.4  7.2  4.6   4.6  22.9  19.6 -0.2     False
# 8  ...  47.7  22.0  14.1  7.7  4.3   5.6  22.6  22.7 -2.1     False
# 9  ...  43.8  24.5  12.8  7.7  4.8   7.2  16.3  16.5 -5.3     False
#
# [10 rows x 29 columns]

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ## Load Stage
# ### Connect to the Database

# %%
project_dir = Path.cwd().parent
secrets_path = project_dir.joinpath("secrets.toml")

with open(secrets_path, "rb") as f:
    secrets = tomllib.load(f)

# database and root user credentials
host = secrets["DATABASE"]["HOST"]
port = secrets["DATABASE"]["PORT"]
db = secrets["DATABASE"]["DB"]

# user credentials
user = secrets["USER"]["USERNAME"]
pwd = secrets["USER"]["PASSWORD"]

# user db url
db_url = f"postgresql://{user}:{pwd}@{host}:{port}/{db}"

# create the engine
engine = create_engine(db_url)

# %% [markdown]
# ### Load: Regular Season Team Statistics

# %%
start_time = time.time()
teams_traditional = team_stats["Teams General Traditional"]
teams_advanced = team_stats["Teams General Advanced"]
teams_misc = team_stats["Teams General Misc"]
teams_clutch = team_stats["Teams Clutch Traditional"]

teams_table_names = [
    "teams_traditional",
    "teams_advanced",
    "teams_misc",
    "teams_clutch",
]

teams_traditional.to_sql(
    name=teams_table_names[0], con=engine, if_exists="replace", index=False
)
teams_advanced.to_sql(
    name=teams_table_names[1], con=engine, if_exists="replace", index=False
)
teams_misc.to_sql(
    name=teams_table_names[2], con=engine, if_exists="replace", index=False
)
teams_clutch.to_sql(
    name=teams_table_names[3], con=engine, if_exists="replace", index=False
)

print(f"Reg Season Done. {time.time() - start_time} total seconds elapsed")

# %% [markdown]
# ### Load: Playoff Team Statistics

# %%
start_time = time.time()
playoffs_traditional = team_stats_playoffs["Teams General Traditional"]
playoffs_advanced = team_stats_playoffs["Teams General Advanced"]
playoffs_misc = team_stats_playoffs["Teams General Misc"]
playoffs_clutch = team_stats_playoffs["Teams Clutch Traditional"]

playoffs_table_names = [
    "playoffs_traditional",
    "playoffs_advanced",
    "playoffs_misc",
    "playoffs_clutch",
]

playoffs_traditional.to_sql(
    name=playoffs_table_names[0], con=engine, if_exists="replace", index=False
)
playoffs_advanced.to_sql(
    name=playoffs_table_names[1], con=engine, if_exists="replace", index=False
)
playoffs_misc.to_sql(
    name=playoffs_table_names[2], con=engine, if_exists="replace", index=False
)
playoffs_clutch.to_sql(
    name=playoffs_table_names[3], con=engine, if_exists="replace", index=False
)

print(f"Playoffs Done. {time.time() - start_time} total seconds elapsed")

# %% [markdown]
# ### Load: Playoff Teams and Champions

# %%
playoff_teams_df.to_sql(
    name="playoff_teams", con=engine, if_exists="replace", index=False
)
playoff_teams_long_df.to_sql(
    name="playoff_teams_long", con=engine, if_exists="replace", index=False
)

champions_df.to_sql(name="champions", con=engine, if_exists="replace", index=False)

# %% [markdown]
# ### Assign Primary Keys

# %%
stats_table_names = teams_table_names + playoffs_table_names
composite_key = '"TEAM", "SEASON"'

with engine.connect() as connection:
    # Add the primary key for each of the stats tables
    for table_name in stats_table_names:
        query = f"ALTER TABLE {table_name} ADD PRIMARY KEY({composite_key});"
        connection.execute(query)
    # Add the primary key for the additional playoff teams and champions tables
    query = f"ALTER TABLE playoff_teams_long ADD PRIMARY KEY({composite_key});"
    connection.execute(query)
    query = 'ALTER TABLE champions ADD PRIMARY KEY("SEASON");'
    connection.execute(query)
